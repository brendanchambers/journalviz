# %%
import sys, signal
from PyQt4 import QtCore, QtGui, QtWebKit

class WebPage(QtWebKit.QWebPage):  
    def __init__(self):
        QtWebKit.QWebPage.__init__(self)
        self.mainFrame().loadFinished.connect(self.handleLoadFinished)

    def process(self, items):
        self._items = iter(items)
        self.fetchNext()
    
    def fetchNext(self):
        try:
            self._url, self._func = next(self._items)
            self.mainFrame().load(QtCore.QUrl(self._url))
        except StopIteration:
            return False
        return True
    
    def handleLoadFinished(self):
        self._func(self._url, self.mainFrame().toHtml())
        if not self.fetchNext():
            print('# processing complete')
            QtGui.qApp.quit()
            
def funcA(url, html):
    print('# processing:', url)
    # do stuff with soup
    
def funcB(url, html):
    print('# processing:', url)
    # do stuff with soup
    
'''    
def get_html(link):        
        q = Request(link)
        q.add_header('User-Agent', 'Mozilla/5.0')
        print(str(q))
        r = urlopen(q).read()
        print(r)
        return r
'''
    

    
# todo use this to fix segfault on second iteration https://stackoverflow.com/questions/21909907/pyqt-class-not-working-for-the-second-usage/21918243#21918243
# Out:
# "    \ndef get_html(link):        \n        q = Request(link)\n        q.add_header('User-Agent', 'Mozilla/5.0')\n        print(str(q))\n        r = urlopen(q).read()\n        print(r)\n        return r\n"

# %%
# temporary backup of the old method, it crashes
'''
import sys  
from PyQt4.QtGui import *  
from PyQt4.QtCore import *  
from PyQt4.QtWebKit import *  


class Render(QWebPage):  
  def __init__(self, url):  
    self.app = QApplication(sys.argv)  
    QWebPage.__init__(self)  
    self.loadFinished.connect(self._loadFinished)  
    self.mainFrame().load(QUrl(url))  
    self.app.exec_()  
  
  def _loadFinished(self, result):  
    self.frame = self.mainFrame()  
    self.app.quit()  
    
def get_html(link):        
        q = Request(link)
        q.add_header('User-Agent', 'Mozilla/5.0')
        print(str(q))
        r = urlopen(q).read()
        print(r)
        return r
'''

# %%
# access PlOS CB abstract
# /html/body/main/div/section/div/div[3]/div/div[1]/p xpath for abstract in plos cb

import urllib
from bs4 import BeautifulSoup

url_string = 'http://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1006171'
r = urllib.urlopen(url_string).read()

soup = BeautifulSoup(r)

abstract = soup.select("div.abstract")[0].text[8:] # get abstract from html & pick off first 8 characters,
                                        # these characters read, "Abstract"
author_summary = soup.select("div.abstract")[1].text[15:] # "author summary"

print(abstract)
print(author_summary)

# %%
# get list of articles to traverse

# test edition 1
edition_a = "http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i04"  # older
edition_b = "http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i02" # recent
edition_a = "http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i04"


url_string = edition_a
r = urllib.urlopen(url_string).read()

soup = BeautifulSoup(r)
research_articles_section = soup.select('.section')[4]
research_articles = research_articles_section.select('.item')

for sample_article in research_articles:
    url = sample_article.select('a')[1].text
    authors = sample_article.select('p')[0].text
    authors = authors.split(',') # todo normalize names for whitespace, \n, etc

    date = sample_article.select('p')[1].text.split('|')[0]
    date = date.split('\n')[1] # todo express this as a datetime object (check formatting across articles)

    title = sample_article.select('a')[0].text
    journal = "PLOS Computational Biology"

    print(url)
    print(authors)
    print(date)
    print(title)

    article_metadata_object = {"url":url, "authors":authors, "date":date, "title":title}

    # todo save as a json file using url as name

# %%
from bs4 import BeautifulSoup
from urllib2 import Request, urlopen

# selector page
# e.g. http://journals.plos.org/ploscompbiol/volume#2018
edition_selector_page = "http://journals.plos.org/ploscompbiol/volume#2017"
list_of_editions = []
print repr(edition_selector_page)
print edition_selector_page

def get_html(link):        
    q = Request(link)
    q.add_header('User-Agent', 'Mozilla/5.0')
    r = urlopen(q).read()
    return r

r = get_html(edition_selector_page)

soup = BeautifulSoup(r,"lxml")

year = 2019 # hacky counter for keeping track of year
links = soup.find_all('a',href=True)  # this returns all the articles, not just the articles for #2017
for link in links:
    
    if len(link.select('img')) > 0: # check for null
        altText = link.select('img')[0]['alt'] 
        if "Journal Cover" in altText: # this is a link we want
            postfix = link['href']
            edition_link = "http://journals.plos.org" + postfix # turn relative link into full path
            month = altText.split("Journal Cover")[0] # month
            month = month.split(' ')[0]
            if "January" in month:
                year = year-1
            print(month, year)
            list_of_editions.append({"url":edition_link,"year":year,"month":month})
            
print(len(list_of_editions))

# todo write list of editions to a json file
# Out:
# 'http://journals.plos.org/ploscompbiol/volume#2017'
# http://journals.plos.org/ploscompbiol/volume#2017
# ('January', 2018)
# ('February', 2018)
# ('March', 2018)
# ('April', 2018)
# ('May', 2018)
# ('June', 2018)
# ('July', 2018)
# ('January', 2017)
# ('February', 2017)
# ('March', 2017)
# ('April', 2017)
# ('May', 2017)
# ('June', 2017)
# ('July', 2017)
# ('August', 2017)
# ('September', 2017)
# ('October', 2017)
# ('November', 2017)
# ('December', 2017)
# ('January', 2016)
# ('February', 2016)
# ('March', 2016)
# ('April', 2016)
# ('May', 2016)
# ('June', 2016)
# ('July', 2016)
# ('August', 2016)
# ('September', 2016)
# ('October', 2016)
# ('November', 2016)
# ('December', 2016)
# ('January', 2015)
# ('February', 2015)
# ('March', 2015)
# ('April', 2015)
# ('May', 2015)
# ('June', 2015)
# ('July', 2015)
# ('August', 2015)
# ('September', 2015)
# ('October', 2015)
# ('November', 2015)
# ('December', 2015)
# ('January', 2014)
# ('February', 2014)
# ('March', 2014)
# ('April', 2014)
# ('May', 2014)
# ('June', 2014)
# ('July', 2014)
# ('August', 2014)
# ('September', 2014)
# ('October', 2014)
# ('November', 2014)
# ('December', 2014)
# ('January', 2013)
# ('February', 2013)
# ('March', 2013)
# ('April', 2013)
# ('May', 2013)
# ('June', 2013)
# ('July', 2013)
# ('August', 2013)
# ('September', 2013)
# ('October', 2013)
# ('November', 2013)
# ('December', 2013)
# ('January', 2012)
# ('February', 2012)
# ('March', 2012)
# ('April', 2012)
# ('May', 2012)
# ('June', 2012)
# ('July', 2012)
# ('August', 2012)
# ('September', 2012)
# ('October', 2012)
# ('November', 2012)
# ('December', 2012)
# ('January', 2011)
# ('February', 2011)
# ('March', 2011)
# ('April', 2011)
# ('May', 2011)
# ('June', 2011)
# ('July', 2011)
# ('August', 2011)
# ('September', 2011)
# ('October', 2011)
# ('November', 2011)
# ('December', 2011)
# ('January', 2010)
# ('February', 2010)
# ('March', 2010)
# ('April', 2010)
# ('May', 2010)
# ('June', 2010)
# ('July', 2010)
# ('August', 2010)
# ('September', 2010)
# ('October', 2010)
# ('November', 2010)
# ('December', 2010)
# ('January', 2009)
# ('February', 2009)
# ('March', 2009)
# ('April', 2009)
# ('May', 2009)
# ('June', 2009)
# ('July', 2009)
# ('August', 2009)
# ('September', 2009)
# ('October', 2009)
# ('November', 2009)
# ('December', 2009)
# ('January', 2008)
# ('February', 2008)
# ('March', 2008)
# ('April', 2008)
# ('May', 2008)
# ('June', 2008)
# ('July', 2008)
# ('August', 2008)
# ('September', 2008)
# ('October', 2008)
# ('November', 2008)
# ('December', 2008)
# ('January', 2007)
# ('February', 2007)
# ('March', 2007)
# ('April', 2007)
# ('May', 2007)
# ('June', 2007)
# ('July', 2007)
# ('August', 2007)
# ('September', 2007)
# ('October', 2007)
# ('November', 2007)
# ('December', 2007)
# ('January', 2006)
# ('February', 2006)
# ('March', 2006)
# ('April', 2006)
# ('May', 2006)
# ('June', 2006)
# ('July', 2006)
# ('August', 2006)
# ('September', 2006)
# ('October', 2006)
# ('November', 2006)
# ('December', 2006)
# ('June', 2006)
# ('July', 2006)
# ('August', 2006)
# ('September', 2006)
# ('October', 2006)
# ('November', 2006)
# ('December', 2006)
# 158

# %%
import json

save_path = "data/ploscompbio_editions.json"

with open(save_path, 'w') as outfile:  
    json.dump(list_of_editions, outfile)
    
print('saved to json file')

# %%
# initialize database

import sqlite3

db = sqlite3.connect('data/test_scrape0.db')
cursor = db.cursor()
cursor.execute('''CREATE TABLE articles(id INTEGER PRIMARYKEY,
                    url TEXT, authors TEXT, date TEXT, title TEXT, abstract TEXT, author_summary TEXT)
                    ''')


db.commit()

# %%
#from lxml import html
# todo finish figuring out the js-rendered scrape and then put article data into a database


# for each edition:

# loop over editions

for edition in list_of_editions[0:3]:
    print(edition)
    
    url_string = edition['url'].decode('utf-8')
    print(url_string)

    #r = get_html(url_string)
    print("scraping...")
    rendered_js = Render(url_string)
    print("js rendered.")
    r_qstring = rendered_js.frame.toHtml()
    r = str(r_qstring.toAscii())
    print("response ready")
    #edition_soup = BeautifulSoup(r,"lxml")
    edition_soup = BeautifulSoup(r,"lxml")
    try:
        research_articles_section = edition_soup.select('.section')[4]
    except:
        research_articles_section = edition_soup.select('.section')[3] # for the javascript loaded pages
    research_articles = research_articles_section.select('.item')

    for sample_article in research_articles:
        url = sample_article.select('a')[1].text
        print(url)
        
        authors = sample_article.select('p')[0].text
        #authors = authors.split(',') # todo normalize names for whitespace, \n, etc # wait, no do this on removal from database

        date = sample_article.select('p')[1].text.split('|')[0]
        date = date.split('\n')[1] # todo express this as a datetime object (check formatting across articles)

        title = sample_article.select('a')[0].text
        journal = "PLOS Computational Biology" 
        
        print("requesting article...")
        # go the the article url and read text
        r = urllib.urlopen(url).read()
        article_soup = BeautifulSoup(r)
        abstract = article_soup.select("div.abstract")[0].text[8:] # get abstract from html & pick off first 8 characters,
                                        # these characters read, "Abstract"
        try:
            author_summary = article_soup.select("div.abstract")[1].text[15:] # "author summary" 
        except: # a few articles don't have author summaries
            author_summary = "No author summary found"
        
        article_data_object = {"url":url, "authors":authors, "date":date, "title":title,"abstract":abstract,
                                  "author_summary":author_summary}
        
        # add article data object to a database        
        cursor.execute('''INSERT INTO articles(url, authors, date, title, abstract, author_summary)
                VALUES(:url, :authors, :date, :title, :abstract, :author_summary)''',
                article_data_object)

        db.commit()
        print('entry added to database')
        
db.close()
print('database closed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c3198045767f> in <module>()
#       7 # loop over editions
#       8
# ----> 9 for edition in list_of_editions[0:3]:
#      10     print(edition)
#      11
#
# NameError: name 'list_of_editions' is not defined

# %%
# rewrite the cell above to avoid segfaults in constructing QApplication

edition_urls = [ed['url'] for ed in list_of_editions]

app = QtGui.QApplication(sys.argv)
webpage = WebPage()
webpage.process(edition_urls)
# Out:
# ['http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i01', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i02', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i03', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i04', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i05', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i06', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v14.i07', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i01', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i02', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i03', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i04', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i05', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i06', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i07', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i08', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i09', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i10', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i11', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v13.i12', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i01', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i02', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i03', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i04', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i05', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i06', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i07', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i08', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i09', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i10', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i11', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v12.i12', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i01', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i02', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i03', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i04', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i05', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i06', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i07', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i08', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i09', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i10', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i11', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v11.i12', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i01', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i02', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i03', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i04', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i05', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i06', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i07', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i08', 'http://journals.plos.org/ploscompbiol/issue?id=10.1371/issue.pcbi.v10.i ...
